# %%
import os

# ✅ Fix OpenMP crash (OMP: Error #15)
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import xml.etree.ElementTree as ET
import json
import chromadb
from transformers import AutoTokenizer, AutoModel
import torch
from tqdm import tqdm
import glob

# %%
# Initialize Hugging Face embedding model
MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"  # Change if needed
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)

# Initialize ChromaDB
chroma_client = chromadb.PersistentClient(path="./chromadb")  # Persistent storage
collection = chroma_client.get_or_create_collection(name="hospice_rules")

# %%
def parse_xml_element(element):
    """
    Recursively parses an XML element into a nested dictionary.
    """
    parsed_data = {"tag": element.tag}

    # If the element has attributes, store them
    if element.attrib:
        parsed_data["attributes"] = element.attrib

    # If the element has text, store it
    if element.text and element.text.strip():
        parsed_data["text"] = element.text.strip()

    # If the element has children, process them
    children = list(element)
    if children:
        parsed_data["children"] = [parse_xml_element(child) for child in children]

    return parsed_data


def flatten_hierarchy(data, parent_key=""):
    """
    Converts hierarchical XML data into a flat format suitable for embedding.
    """
    flat_data = []
    if isinstance(data, dict):
        tag = data.get("tag", "UNKNOWN")
        text = data.get("text", "")
        attributes = json.dumps(data.get("attributes", {}))
        key = f"{parent_key}/{tag}" if parent_key else tag

        # Create a formatted string for embedding
        entry = {
            "key": key,
            "content": f"Tag: {tag}, Attributes: {attributes}, Text: {text}".strip()
        }
        flat_data.append(entry)

        # Process children recursively
        for child in data.get("children", []):
            flat_data.extend(flatten_hierarchy(child, key))

    return flat_data


def chunk_text(text, chunk_size=200):
    """
    Splits long text into smaller chunks to improve embeddings and retrieval.
    """
    words = text.split()
    return [" ".join(words[i : i + chunk_size]) for i in range(0, len(words), chunk_size)]


def generate_embedding(text):
    """
    Generate embeddings using a Hugging Face transformer model.
    """
    tokens = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        output = model(**tokens)
        embedding = output.last_hidden_state[:, 0, :].squeeze().tolist()
    return embedding


def process_xml_file(file_path):
    """
    Parses and processes an XML file, returning a list of structured data.
    """
    tree = ET.parse(file_path)
    root = tree.getroot()
    parsed_data = parse_xml_element(root)
    flat_data = flatten_hierarchy(parsed_data)
    return flat_data

# %%
# ✅ **Automatically Find All XML Files in `data/` Folder**
xml_folder = "data/"
xml_files = glob.glob(os.path.join(xml_folder, "*.xml"))  # Finds all XML files in `data/`
if not xml_files:
    print(f"No XML files found in {xml_folder}. Please place XML files there.")
    exit()

print(f"📂 Found {len(xml_files)} XML files in `{xml_folder}`: {xml_files}")
# Out:
# 📂 Found 2 XML files in `data/`: ['data\\2025 Hospice Final Rule.xml', 'data\\2025 Hospice Proposed Rule.xml']

# %%
# ✅ **Process Each XML File**
for file in xml_files:
    print(f"📄 Processing `{file}`...")

    # Parse and flatten XML data
    structured_data = process_xml_file(file)

    # Generate embeddings and store in ChromaDB
    for i, entry in tqdm(enumerate(structured_data), total=len(structured_data), desc=f"🔄 Embedding `{file}`"):
        chunks = chunk_text(entry["content"])  # ✅ **Chunk long text**
        
        for j, chunk in enumerate(chunks):
            embedding = generate_embedding(chunk)

            # Add to ChromaDB
            collection.add(
                ids=[f"{file}-{i}-{j}"],
                embeddings=[embedding],
                metadatas=[{"source": file, "key": entry["key"], "text": chunk}]
            )

print("✅ Data successfully stored in ChromaDB!")
# Out:
# 📄 Processing `data\2025 Hospice Final Rule.xml`...
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   0%|          | 0/1139 [00:00<?, ?it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-610-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-611-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-612-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-613-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-614-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-615-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-616-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-617-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-618-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-619-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-620-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-621-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-622-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-623-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-624-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-625-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-626-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-627-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-628-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-629-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-630-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-631-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-632-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-633-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-634-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-635-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-636-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-637-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-638-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-639-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-640-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-641-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-642-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-643-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-644-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-645-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-646-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-647-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-648-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-649-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-650-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-651-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-652-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-653-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-654-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-655-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-656-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-657-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-658-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-659-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-660-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-661-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-662-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-663-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-664-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-665-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-666-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-667-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-668-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-669-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-670-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-671-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-672-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-673-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-674-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-675-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-676-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-677-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-678-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-679-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-680-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-681-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-682-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-683-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-684-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-685-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-686-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-687-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-688-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-689-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-690-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-691-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-692-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-692-1
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-693-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-694-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-695-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-696-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-697-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-698-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-699-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-700-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-701-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-702-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-703-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-703-1
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-704-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-705-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-706-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-707-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-708-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-709-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-710-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-711-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-712-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-713-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-714-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-715-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-716-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-717-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-718-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-719-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-720-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-721-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-722-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-723-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-724-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-725-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-726-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-727-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-728-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-729-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-730-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-731-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-732-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-733-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-734-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-735-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-736-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-737-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-738-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-739-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-740-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-741-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-742-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-743-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-744-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-745-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-746-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-747-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-748-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-749-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-750-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-751-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-752-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-753-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-754-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-755-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-756-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-757-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-758-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-759-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-760-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-761-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-762-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-763-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-764-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-765-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-766-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-767-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-768-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-769-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-770-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-771-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-772-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-773-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-774-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-775-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-776-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-777-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-778-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-779-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-780-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-781-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-781-1
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-782-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-783-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-784-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-785-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-786-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-787-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-788-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-789-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-790-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-791-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-792-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-793-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-794-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-795-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-796-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-797-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-798-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-799-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-800-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-801-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-802-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-803-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-804-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-805-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-806-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-807-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-808-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-809-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-809-1
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-810-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-811-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-812-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-813-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-814-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-815-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-816-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-817-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-818-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-819-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-820-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-821-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-822-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-823-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-824-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-825-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-826-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-827-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-828-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-829-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-830-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-831-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-832-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-833-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-834-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-835-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-836-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-837-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-838-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-839-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-840-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-841-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-842-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-843-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-844-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-845-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-846-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-847-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-848-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-849-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-850-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-851-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-852-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-853-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-854-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-855-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-856-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-857-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-858-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-859-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-860-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-861-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-862-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-863-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-864-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-865-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-866-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-867-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-868-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-869-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-870-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-871-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-872-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-873-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-874-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-875-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-876-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-877-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-878-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-879-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-880-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-881-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-882-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-883-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-884-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-885-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-886-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-887-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-888-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-889-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-890-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-891-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-892-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-893-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-894-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-895-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-896-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-897-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-898-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-899-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-0-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-0-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   0%|          | 1/1139 [00:00<07:56,  2.39it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-1-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-1-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-2-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-2-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-3-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-3-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   0%|          | 4/1139 [00:00<02:07,  8.93it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-4-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-4-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-5-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-5-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-6-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-6-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-7-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-7-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-8-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-8-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   1%|          | 9/1139 [00:00<01:02, 18.20it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-9-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-9-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-10-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-10-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-11-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-11-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-12-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-12-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-13-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-13-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   1%|          | 14/1139 [00:00<00:44, 25.47it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-14-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-14-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-15-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-15-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-16-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-16-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-17-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-17-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   2%|▏         | 18/1139 [00:00<00:40, 27.88it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-18-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-18-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-19-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-19-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-20-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-20-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-21-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-21-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-22-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-22-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   2%|▏         | 23/1139 [00:01<00:34, 32.40it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-23-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-23-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-24-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-24-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-25-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-25-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-26-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-26-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   2%|▏         | 27/1139 [00:01<00:32, 34.32it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-27-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-27-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-28-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-28-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-29-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-29-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-30-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-30-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-31-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-31-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   3%|▎         | 32/1139 [00:01<00:30, 36.71it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-32-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-32-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-33-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-33-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-34-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-34-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-35-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-35-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   3%|▎         | 36/1139 [00:01<00:35, 31.32it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-36-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-36-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-37-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-37-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-38-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-38-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-39-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-39-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   4%|▎         | 40/1139 [00:01<00:33, 32.64it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-40-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-40-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-41-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-41-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-42-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-42-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-43-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-43-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   4%|▍         | 44/1139 [00:01<00:36, 30.21it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-44-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-44-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-45-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-45-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-46-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-46-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-47-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-47-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-48-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-48-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   4%|▍         | 49/1139 [00:01<00:34, 31.84it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-49-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-49-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-50-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-50-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-51-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-51-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-52-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-52-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   5%|▍         | 53/1139 [00:01<00:36, 30.05it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-53-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-53-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-53-1
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-53-1
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-54-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-54-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-55-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-55-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-56-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-56-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   5%|▌         | 57/1139 [00:02<00:38, 28.17it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-57-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-57-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-58-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-58-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-59-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-59-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-60-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-60-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-61-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-61-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   5%|▌         | 62/1139 [00:02<00:37, 29.03it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-62-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-62-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-63-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-63-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-64-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-64-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-65-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-65-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-66-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-66-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   6%|▌         | 67/1139 [00:02<00:32, 33.34it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-67-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-67-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-68-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-68-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-69-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-69-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-70-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-70-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-71-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-71-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   6%|▋         | 72/1139 [00:02<00:29, 35.77it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-72-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-72-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-73-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-73-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-74-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-74-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-75-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-75-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-76-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-76-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   7%|▋         | 77/1139 [00:02<00:29, 35.51it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-77-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-77-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-78-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-78-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-79-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-79-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-80-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-80-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   7%|▋         | 81/1139 [00:02<00:30, 35.07it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-81-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-81-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-82-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-82-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-83-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-83-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-84-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-84-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   7%|▋         | 85/1139 [00:02<00:32, 32.65it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-85-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-85-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-86-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-86-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-87-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-87-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-88-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-88-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   8%|▊         | 89/1139 [00:03<00:31, 33.07it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-89-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-89-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-90-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-90-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-91-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-91-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-92-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-92-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   8%|▊         | 93/1139 [00:03<00:30, 34.71it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-93-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-93-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-94-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-94-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-95-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-95-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-96-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-96-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   9%|▊         | 97/1139 [00:03<00:31, 33.55it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-97-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-97-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-98-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-98-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-99-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-99-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-100-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-100-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-100-1
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-100-1
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-100-2
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-100-2
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   9%|▉         | 101/1139 [00:03<00:39, 26.02it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-101-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-101-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-102-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-102-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-102-1
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-102-1
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-102-2
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-102-2
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-103-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-103-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   9%|▉         | 104/1139 [00:03<00:46, 22.17it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-104-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-104-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-105-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-105-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-106-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-106-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-107-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-107-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:   9%|▉         | 108/1139 [00:03<00:40, 25.56it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-108-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-108-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-109-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-109-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-110-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-110-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-111-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-111-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-112-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-112-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  10%|▉         | 113/1139 [00:03<00:33, 30.31it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-113-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-113-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-114-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-114-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-115-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-115-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-116-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-116-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-117-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-117-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  10%|█         | 118/1139 [00:04<00:29, 34.73it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-118-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-118-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-119-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-119-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-120-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-120-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-121-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-121-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-122-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-122-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  11%|█         | 123/1139 [00:04<00:27, 37.62it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-123-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-123-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-124-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-124-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-125-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-125-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-126-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-126-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-127-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-127-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  11%|█         | 128/1139 [00:04<00:25, 39.90it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-128-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-128-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-129-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-129-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-130-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-130-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-131-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-131-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-132-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-132-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  12%|█▏        | 133/1139 [00:04<00:30, 32.88it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-133-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-133-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-134-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-134-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-135-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-135-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-135-1
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-135-1
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-136-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-136-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  12%|█▏        | 137/1139 [00:04<00:35, 28.17it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-137-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-137-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-138-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-138-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-139-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-139-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-140-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-140-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  12%|█▏        | 141/1139 [00:04<00:34, 28.95it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-141-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-141-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-142-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-142-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-143-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-143-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-144-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-144-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-144-1
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-144-1
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  13%|█▎        | 145/1139 [00:04<00:37, 26.73it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-145-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-145-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-145-1
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-145-1
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-146-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-146-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-147-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-147-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  13%|█▎        | 148/1139 [00:05<00:37, 26.36it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-148-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-148-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-149-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-149-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-150-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-150-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-151-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-151-0
# 🔄 Embedding `data\2025 Hospice Final Rule.xml`:  13%|█▎        | 152/1139 [00:05<00:34, 28.78it/s]Add of existing embedding ID: data\2025 Hospice Final Rule.xml-152-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-152-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-153-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-153-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-154-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-154-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-155-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-155-0
# Add of existing embedding ID: data\2025 Hospice Final Rule.xml-156-0
# Insert of existing embedding ID: data\2025 Hospice Final Rule.xml-156-0
# ...
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-807-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-807-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-808-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-808-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  90%|████████▉ | 809/900 [00:23<00:02, 35.15it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-809-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-809-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-809-1
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-809-1
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-810-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-810-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-811-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-811-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-812-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-812-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  90%|█████████ | 813/900 [00:23<00:02, 30.18it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-813-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-813-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-814-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-814-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-815-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-815-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-816-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-816-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  91%|█████████ | 817/900 [00:23<00:02, 31.86it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-817-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-817-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-818-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-818-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-819-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-819-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-820-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-820-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  91%|█████████ | 821/900 [00:24<00:02, 32.35it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-821-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-821-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-822-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-822-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-823-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-823-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-824-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-824-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  92%|█████████▏| 825/900 [00:24<00:02, 32.86it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-825-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-825-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-826-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-826-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-827-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-827-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-828-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-828-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-829-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-829-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  92%|█████████▏| 830/900 [00:24<00:01, 35.69it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-830-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-830-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-831-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-831-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-832-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-832-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-833-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-833-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-834-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-834-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  93%|█████████▎| 835/900 [00:24<00:01, 38.12it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-835-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-835-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-836-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-836-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-837-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-837-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-838-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-838-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-839-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-839-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  93%|█████████▎| 840/900 [00:24<00:01, 39.28it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-840-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-840-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-841-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-841-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-842-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-842-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-843-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-843-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  94%|█████████▍| 844/900 [00:24<00:01, 38.76it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-844-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-844-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-845-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-845-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-846-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-846-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-847-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-847-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-848-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-848-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  94%|█████████▍| 849/900 [00:24<00:01, 40.59it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-849-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-849-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-850-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-850-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-851-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-851-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-852-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-852-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-853-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-853-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  95%|█████████▍| 854/900 [00:24<00:01, 40.61it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-854-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-854-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-855-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-855-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-856-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-856-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-857-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-857-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-858-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-858-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  95%|█████████▌| 859/900 [00:25<00:01, 38.39it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-859-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-859-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-860-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-860-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-861-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-861-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-862-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-862-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  96%|█████████▌| 863/900 [00:25<00:00, 38.12it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-863-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-863-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-864-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-864-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-865-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-865-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-866-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-866-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-867-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-867-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  96%|█████████▋| 868/900 [00:25<00:00, 39.78it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-868-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-868-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-869-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-869-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-870-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-870-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-871-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-871-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-872-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-872-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  97%|█████████▋| 873/900 [00:25<00:00, 39.95it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-873-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-873-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-874-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-874-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-875-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-875-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-876-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-876-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-877-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-877-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  98%|█████████▊| 878/900 [00:25<00:00, 38.72it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-878-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-878-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-879-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-879-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-880-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-880-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-881-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-881-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-882-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-882-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  98%|█████████▊| 883/900 [00:25<00:00, 40.56it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-883-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-883-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-884-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-884-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-885-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-885-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-886-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-886-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-887-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-887-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  99%|█████████▊| 888/900 [00:25<00:00, 41.30it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-888-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-888-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-889-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-889-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-890-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-890-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-891-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-891-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-892-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-892-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`:  99%|█████████▉| 893/900 [00:25<00:00, 41.94it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-893-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-893-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-894-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-894-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-895-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-895-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-896-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-896-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-897-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-897-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`: 100%|█████████▉| 898/900 [00:26<00:00, 39.09it/s]Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-898-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-898-0
# Add of existing embedding ID: data\2025 Hospice Proposed Rule.xml-899-0
# Insert of existing embedding ID: data\2025 Hospice Proposed Rule.xml-899-0
# 🔄 Embedding `data\2025 Hospice Proposed Rule.xml`: 100%|██████████| 900/900 [00:26<00:00, 34.54it/s]
# ✅ Data successfully stored in ChromaDB!

# %%
query_text = "hospice payment update"
query_embedding = generate_embedding(query_text)

results = collection.query(
    query_embeddings=[query_embedding],
    n_results=5  # Number of top results
)

print("🔎 Search Results:", results)
# Out:
# 🔎 Search Results: {'ids': [['data\\2025 Hospice Proposed Rule.xml-213-1', 'data\\2025 Hospice Final Rule.xml-24-0', 'data\\2025 Hospice Proposed Rule.xml-39-0', 'data\\2025 Hospice Final Rule.xml-377-1', 'data\\2025 Hospice Proposed Rule.xml-64-0']], 'embeddings': None, 'documents': [[None, None, None, None, None]], 'uris': None, 'data': None, 'metadatas': [[{'key': 'PRORULE/SUPLINF/P', 'source': 'data\\2025 Hospice Proposed Rule.xml', 'text': 'hospice payment update percentage in the FY 2025 final rule.'}, {'key': 'RULE/PREAMB/FURINF/P', 'source': 'data\\2025 Hospice Final Rule.xml', 'text': 'Tag: P, Attributes: {}, Text: For general questions about hospice payment policy, send your inquiry via email to:'}, {'key': 'PRORULE/PREAMB/FURINF/P', 'source': 'data\\2025 Hospice Proposed Rule.xml', 'text': 'Tag: P, Attributes: {}, Text: For general questions about hospice payment policy, send your inquiry via email to:'}, {'key': 'RULE/SUPLINF/P', 'source': 'data\\2025 Hospice Final Rule.xml', 'text': 'pose financial risks to hospices when enrolling such patients. Commenters stated that the current bundled per diem payment is not reflective of the increased expenses associated with higher-cost and certain patient subgroups. As we continue to focus on improved access and value within the hospice benefit, we solicited additional information on the potential implementation of a payment mechanism to account for the increased costs of providing more intensive palliative treatments.'}, {'key': 'PRORULE/SUPLINF/P', 'source': 'data\\2025 Hospice Proposed Rule.xml', 'text': 'Tag: P, Attributes: {}, Text: Section III.A.4 of this proposed rule proposes updates to the hospice payment rates.'}]], 'distances': [[9.868145942687988, 10.479599952697754, 10.479599952697754, 11.388520240783691, 12.01854133605957]], 'included': [<IncludeEnum.distances: 'distances'>, <IncludeEnum.documents: 'documents'>, <IncludeEnum.metadatas: 'metadatas'>]}

# %%
from ctransformers import AutoModelForCausalLM

# ✅ Update the model path
MODEL_PATH = "models/falcon-7b-instruct.ggccv1.q5_1.bin"  # Adjust path if needed

# ✅ Load Falcon-7B with `ctransformers`
llm = AutoModelForCausalLM.from_pretrained(
    MODEL_PATH,
    model_type="falcon",  # Specify Falcon model
    gpu_layers=0  # Set > 0 if you have GPU
)

# ✅ Function to chat with Falcon
def ask_falcon(question):
    prompt = f"### Instruction: Answer the following question using your knowledge.\n\nQuestion: {question}\n\nAnswer:"
    response = llm(prompt, max_new_tokens=512)
    return response

# %%
# Example
question = "What are the updates to the hospice payment rates for 2025?"
response = ask_falcon(question)
print("🤖 Falcon-7B Response:", response)
# Out:
# 🤖 Falcon-7B Response:  In 2025, the hospice payment rates are increasing by 1.76% and will impact reimbursements paid by insurance companies to hospice care providers. Hospice providers are expected to receive an additional $7.8 billion in funding. Hospice services covered by Medicare will continue to be reimbursed at the current rate of $13.44 per day.
